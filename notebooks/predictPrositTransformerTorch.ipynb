# %% [markdown]
# ### Imports

# %%
from tape import ProteinBertForValuePredictionFragmentationProsit
import numpy as np
from tape import TAPETokenizer
from PrositTransformer.DataHandler import pad_sequences
import torch

# %% [markdown]
# ### Data pre-processors

# %% [markdown]
# ##### Charge pre-processors

# %%
CHARGES = [1, 2, 3, 4, 5, 6]
def get_precursor_charge_onehot(charges):
    array = np.zeros([len(charges), max(CHARGES)], dtype=int)
    for i, precursor_charge in enumerate(charges):
        array[i, precursor_charge - 1] = 1
    return array

# %% [markdown]
# ##### Peptide pre-processors

# %%
tokenizer = TAPETokenizer()
def TokenizePeptides(peptides):
    input_ids = pad_sequences([tokenizer.encode(p) for p in peptide_sequences])
    return input_ids, np.ones_like(input_ids)

# %% [markdown]
# ### Toy data

# %%
collision_energy, charge, peptide_sequences = np.hstack([0.24, 0.36]), get_precursor_charge_onehot([1,3]), ["AGM", "QPSEP"]

# %%
input_ids, input_mask = TokenizePeptides(peptide_sequences)

# %%
toy_data = {
    'collision_energy': torch.FloatTensor(collision_energy.astype(np.float32)),
    'charge': torch.FloatTensor(charge.astype(np.float32)),
    'input_ids' : torch.from_numpy(input_ids.astype(np.int64)),
    'input_mask' : torch.from_numpy(input_mask.astype(np.int64))
        }

# %% [markdown]
# ### Get model

# %%
model = ProteinBertForValuePredictionFragmentationProsit.from_pretrained("/sdd/berzelius/delta_-0.025")

# %% [markdown]
# ### Load GPU

# %%
model = model.to(torch.device('cuda:0'))
toy_data = {name: tensor.cuda(device=torch.device('cuda:0'), non_blocking=True)
                     for name, tensor in toy_data.items()}

# %% [markdown]
# ### Predict

# %%
model(**toy_data)[0].cpu().detach().numpy()
# Out:
# array([[-4.21155244e-02, -2.90694050e-02, -2.68873107e-02,
#         -2.09047627e-02, -2.90646609e-02, -2.68878061e-02,
#         -9.80041921e-02, -2.89471783e-02, -2.67911367e-02,
#         -1.67832643e-01, -2.08295155e-02, -2.68641748e-02,
#         -5.99793792e-02, -3.19970027e-02, -2.61585228e-02,
#         -9.90708619e-02, -1.49606913e-02, -2.66275220e-02,
#         -1.79907382e-02, -3.22534889e-02, -2.61591058e-02,
#         -7.34631866e-02,  2.97731757e-02, -2.61704400e-02,
#         -4.58306670e-02, -3.89692672e-02, -2.63918173e-02,
#         -8.14944059e-02, -2.59719733e-02, -2.46919021e-02,
#         -1.09346211e-02, -2.59443931e-02, -2.64690481e-02,
#         -6.87328503e-02, -3.25176343e-02, -1.79836620e-02,
#         -1.18352324e-02,  5.97040802e-02, -2.22637262e-02,
#         -4.08426449e-02, -3.13226245e-02,  1.97615884e-02,
#         -1.52677596e-02, -2.75294073e-02,  7.15912282e-02,
#         -7.57587701e-03, -2.54582744e-02,  1.05183810e-01,
#         -1.22921839e-02, -1.83842182e-02,  1.27559304e-01,
#          2.97696665e-02,  6.00165054e-02,  1.14201248e-01,
#          1.33123919e-01,  1.12347826e-02,  3.00716430e-01,
#          2.19885528e-01, -5.20160422e-03,  4.64163646e-02,
#          5.67376465e-02,  3.51182818e-02,  6.82394683e-01,
#          2.21188635e-01,  2.46882364e-02,  2.54022211e-01,
#          8.50259513e-03, -4.30843122e-02,  5.19184947e-01,
#          2.71838516e-01,  6.45450503e-03,  2.79656619e-01,
#          9.28418934e-02,  7.56584108e-04,  2.70156115e-01,
#          3.02850962e-01,  2.05389410e-02,  3.19416672e-02,
#          8.14375430e-02,  2.91665286e-01,  2.14993089e-01,
#          3.80765647e-01,  8.04983228e-02,  1.44636512e-01,
#          2.96306685e-02, -2.59103626e-03,  6.29895031e-01,
#          2.70463020e-01,  5.01696020e-02,  5.52652180e-02,
#          1.36939809e-02,  1.68384016e-02,  1.22118875e-01,
#          2.36784190e-01,  1.57816172e-01,  5.52698895e-02,
#          1.30188465e-02,  1.25869364e-03,  1.65164351e-01,
#          1.43054888e-01,  3.38891476e-01, -2.75934786e-02,
#          1.04647428e-02, -1.38005912e-02,  9.12393928e-02,
#          7.59471804e-02,  9.44576785e-03, -8.87433067e-03,
#          5.52274287e-04,  1.52936593e-01,  5.65811634e-01,
#          2.93438211e-02,  5.73359281e-02, -1.88542716e-02,
#         -8.34167562e-03,  2.75449939e-02, -5.03396522e-03,
#          7.52743334e-03,  1.39069915e-01, -4.16037664e-02,
#         -1.68411974e-02,  2.22634245e-02, -2.61112563e-02,
#         -5.58633171e-03,  1.90642461e-01, -3.86073291e-02,
#         -2.09039748e-02,  1.06953673e-01, -3.41021717e-02,
#         -1.20675396e-02,  2.08699524e-01, -4.08765823e-02,
#         -2.46601403e-02,  4.06225696e-02, -5.83449304e-02,
#         -1.57901663e-02,  2.29181617e-01, -4.23941910e-02,
#         -2.65283920e-02,  8.10375363e-02,  2.50297666e-01,
#         -2.00827606e-02,  1.73378721e-01, -7.65223056e-04,
#         -2.71351710e-02,  9.57363397e-02, -9.83867869e-02,
#         -2.63791718e-02,  1.26741305e-01, -2.18541846e-02,
#         -2.88453475e-02,  1.97211772e-01, -1.70697659e-01,
#         -2.15794332e-02,  1.11277446e-01, -5.12376875e-02,
#         -1.58657525e-02,  1.32354394e-01, -1.82663888e-01,
#         -2.49905586e-02,  8.52756277e-02, -1.17459282e-01,
#          3.52012739e-02,  2.29194649e-02, -1.49490878e-01,
#         -8.21299106e-02,  1.83398612e-02, -7.01093227e-02,
#         -3.33014995e-01,  8.09658095e-02, -5.54305613e-01,
#         -1.66614041e-01,  7.30732158e-02, -3.09650481e-01],
#        [ 2.08857149e-01, -4.78389710e-02, -4.54327017e-02,
#         -3.86308171e-02, -4.78410870e-02, -4.54329774e-02,
#          4.50058818e-01, -4.75844443e-02, -4.54023704e-02,
#          3.62503886e-01, -4.46445383e-02, -4.54490855e-02,
#          1.53278852e+00, -2.88248137e-02, -4.47974391e-02,
#          3.53893936e-02, -4.72824983e-02, -4.44042534e-02,
#          6.39006615e-01, -4.20899168e-02, -4.37122509e-02,
#          7.22538978e-02, -4.60462198e-02, -4.45326902e-02,
#          4.71062303e-01, -4.31336164e-02, -4.31718156e-02,
#         -4.30249274e-02, -4.44499664e-02, -4.35263105e-02,
#          5.27394116e-01, -4.27877158e-02, -4.37984727e-02,
#         -2.39270851e-02, -4.64791991e-02, -4.33220081e-02,
#          5.97233295e-01, -4.00950126e-02, -5.05002476e-02,
#          2.66721398e-02, -5.17594777e-02, -4.48544361e-02,
#          4.86058474e-01, -3.84489596e-02, -4.82167527e-02,
#          2.70153657e-02, -3.50499526e-02, -4.21570316e-02,
#          5.18231094e-01, -3.57476696e-02, -2.50875130e-02,
#          1.20310143e-01, -2.13411935e-02, -4.43249121e-02,
#          4.96751308e-01, -4.70455065e-02, -4.94538620e-02,
#          2.49927878e-01,  1.08526722e-01, -4.14652936e-02,
#          4.09781963e-01, -5.66781610e-02, -4.51003052e-02,
#          2.39169836e-01,  2.32071429e-02, -4.39736024e-02,
#          3.07162911e-01, -4.32697535e-02, -6.01918548e-02,
#          2.24213749e-01,  1.22502342e-01, -4.14391570e-02,
#          1.80293709e-01, -4.55015451e-02, -4.72236350e-02,
#          3.23729962e-02,  3.03872675e-03, -4.21764366e-02,
#          1.73575357e-01, -3.72180417e-02, -5.69205545e-02,
#         -1.68561190e-03, -5.11189178e-03, -4.19422127e-02,
#          2.10913606e-02, -4.68176976e-02, -4.04895283e-02,
#         -6.42043725e-03, -9.11124051e-03, -4.18110639e-02,
#         -1.39799323e-02, -5.66546768e-02, -3.73768546e-02,
#         -2.72463914e-02, -1.86017640e-02, -4.16985340e-02,
#         -2.89728735e-02, -4.72985022e-02, -4.17179056e-02,
#         -3.60682495e-02, -1.95463635e-02, -4.01150994e-02,
#         -4.33970988e-02, -5.79319671e-02, -4.73323464e-02,
#         -4.12707664e-02, -2.43741684e-02, -4.36873920e-02,
#         -4.58381958e-02, -5.18451408e-02, -4.89960462e-02,
#         -4.40512486e-02, -2.37722546e-02, -3.98430116e-02,
#         -4.60119806e-02, -5.88918477e-02, -3.54043171e-02,
#         -4.49686944e-02, -3.67366076e-02, -4.03646678e-02,
#         -4.57098633e-02, -5.62751070e-02, -4.43167798e-02,
#         -4.44920585e-02, -3.44239771e-02, -4.19382714e-02,
#         -4.49310131e-02, -6.71203509e-02, -5.29738106e-02,
#         -4.50162850e-02, -4.05408666e-02, -4.31029163e-02,
#         -4.46906351e-02, -5.20213395e-02, -5.14771491e-02,
#         -4.45409268e-02, -3.74558084e-02, -4.50416170e-02,
#         -4.43319827e-02, -5.94357774e-02, -9.94744003e-02,
#         -4.43126149e-02, -3.70317139e-02, -4.47461270e-02,
#         -4.46378291e-02, -5.30600473e-02, -9.64508057e-02,
#         -4.46152948e-02, -3.67215201e-02, -4.30048555e-02,
#         -4.47294228e-02, -3.35089043e-02, -5.96993491e-02,
#         -4.46050093e-02, -3.42608914e-02, -4.36536893e-02,
#         -4.45457399e-02, -3.36836949e-02, -7.03511313e-02,
#         -4.48306687e-02, -3.72844376e-02, -4.60018665e-02,
#         -4.49531451e-02, -3.55197303e-02, -5.12894243e-02,
#         -4.38163355e-02, -4.37201522e-02, -2.98431721e-02,
#         -3.92602757e-02, -3.67096514e-02, -5.68856224e-02,
#         -4.98332307e-02, -4.56972793e-02, -3.99661139e-02]], dtype=float32)
