# %%
import h5py

# %%
path = "/sdd/PrositToTapeDataConverter/hdf5/hcd/HDF5"

# %%
# !ls {path}
# Out:
# prediction_hcd_ho.hdf5	prediction_hcd_train.hdf5  prediction_hcd_valid.hdf5

# %%
f = h5py.File(f'{path}/prediction_hcd_ho.hdf5', 'r')

# %%
data = dict()
for k in list(f.keys()):
    data[k] = f[k]

# %%
for i in range(2):
    print(f"----- {i} -----")
    for k in data.keys():
        print(f'{k}: ', data[k][i])
    print("------------------\n")
# Out:
# ----- 0 -----
# collision_energy:  30.0
# collision_energy_aligned_normed:  0.31707072
# collision_energy_normed:  0.3
# intensities_pred:  [ 8.45218226e-02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.20360285e-01  0.00000000e+00
#   0.00000000e+00  3.49952638e-01  0.00000000e+00  0.00000000e+00
#   1.27388760e-01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  2.73813784e-01  1.20183071e-02
#   0.00000000e+00  1.30678499e-02  0.00000000e+00  0.00000000e+00
#   5.55208564e-01  2.33601239e-02  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  3.50255817e-01  6.36682585e-02
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   7.63494447e-02  6.71867728e-01  1.00881048e-02  0.00000000e+00
#   0.00000000e+00  9.53657291e-05  5.46252206e-02  4.18478191e-01
#   1.10412284e-03  0.00000000e+00  0.00000000e+00  0.00000000e+00
# ...
